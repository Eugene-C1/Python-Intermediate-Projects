# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load csv to Dataframe
df = pd.read_csv(r'C:\Users\cameu\Desktop\Python Projects\1. Web Scraper\Outputs\raw_city_temp.csv')

# %%
df2 = df.groupby('City_Name').mean(numeric_only=True).reset_index()
df2
# Out:
#                  City_Name  Temperature  Feels_Like   Humidity  Wind_Speed
# 0                    Japan    26.240000   26.240000  59.000000    4.120000
# 1                   London    21.760000   21.787500  68.750000    0.560000
# 2               Marunouchi    26.123333   26.123333  59.333333    4.803333
# 3  National Capital Region    35.930000   42.930000  57.500000    4.027500
# 4                 New York    13.062500   12.955000  97.000000    3.495000
# 5                   Sydney    18.607500   18.615000  80.000000    2.187500

# %%
plt.figure(figsize=(10, 5))

plt.bar(df2['City_Name'], df2['Temperature'])

plt.title('Average Temperature by City')
plt.xlabel('City')
plt.ylabel('Temperature')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.bar(df2['City_Name'], df2['Feels_Like'])

plt.title('Average Feels Like Temperature by City')
plt.xlabel('City')
plt.ylabel('Temperature')

plt.tight_layout()
plt.show()
