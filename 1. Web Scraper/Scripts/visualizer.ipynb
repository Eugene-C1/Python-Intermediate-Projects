# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Load csv to Dataframe
df = pd.read_csv(r'C:\Users\cameu\Desktop\Python Projects\1. Web Scraper\Outputs\raw_city_temp.csv')

# %%
df2 = df.groupby('City_Name').mean(numeric_only=True).reset_index()
df2
# Out:
#                  City_Name  Temperature  Feels_Like   Humidity  Wind_Speed
# 0                    Japan    26.240000   26.240000  59.000000    4.120000
# 1                   London    22.406667   22.458333  67.166667    0.820000
# 2               Marunouchi    26.038000   26.134000  60.000000    5.350000
# 3  National Capital Region    35.930000   42.930000  57.333333    4.175000
# 4                 New York    13.068333   12.963333  97.000000    3.873333
# 5                   Sydney    18.588333   18.593333  80.000000    2.145000

# %%
plt.figure(figsize=(10, 5))

plt.bar(df2['City_Name'], df2['Temperature'])

plt.title('Average Temperature by City')
plt.xlabel('City')
plt.ylabel('Temperature')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 5))

plt.bar(df2['City_Name'], df2['Feels_Like'])

plt.title('Average Feels Like Temperature by City')
plt.xlabel('City')
plt.ylabel('Temperature')

plt.tight_layout()
plt.show()
