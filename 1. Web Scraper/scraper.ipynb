# %%
# Import dependencies
from bs4 import BeautifulSoup
import requests
import pandas as pd
import os
from dotenv import load_dotenv

# %%
# Load API key
load_dotenv()
api_key = os.getenv('API_KEY')

# %%
# Send GET Request (Getting the lat and lon of Manila)
url = f'http://api.openweathermap.org/geo/1.0/direct?q=Manila&limit=5&appid={api_key}'
response = requests.get(url)

# %%
# Check if the request was successful
if response.status_code == 200:
    # Convert response to JSON
    data = response.json()
    print(data)
else:
    print(f'Error: {response.status_code}')
# Out:
# [{'name': 'Manila', 'local_names': {'fy': 'Manilla', 'cv': 'Манила', 'ko': '마닐라', 'be': 'Маніла', 'sk': 'Manila', 'fr': 'Manille', 'lv': 'Manila', 'hy': 'Մանիլա', 'hr': 'Manila', 'pt': 'Manila', 'sl': 'Manila', 'kn': 'ಮನಿಲ', 'an': 'Manila', 'ru': 'Манила', 'ar': 'مانيلا', 'tr': 'Manila', 'tl': 'Maynila', 'ur': 'منیلا', 'kk': 'Манила', 'pa': 'ਮਨੀਲਾ', 'ta': 'மணிலா', 'bn': 'ম্যানিলা', 'la': 'Manila', 'uk': 'Маніла', 'ia': 'Manila', 'ha': 'Manila', 'ba': 'Манила', 'cy': 'Manila', 'ga': 'Mainile', 'sh': 'Manila', 'ms': 'Manila', 'fo': 'Manila', 'ie': 'Manila', 'ne': 'मनिला', 'yo': 'Manila', 'uz': 'Manila', 'ja': 'マニラ', 'yi': 'מאנילא', 'de': 'Manila', 'eo': 'Manilo', 'mg': 'Manille', 'hu': 'Manila', 'id': 'Manila', 'ky': 'Манила', 'ro': 'Manila', 'lt': 'Manila', 'af': 'Manila', 'bs': 'Manila', 'km': 'ម៉ានីល', 'gl': 'Manila', 'sw': 'Manila', 'ug': 'مانىلا', 'it': 'Manila', 'ku': 'Manîla', 'te': 'మనీలా', 'th': 'มะนิลา', 'ca': 'Manila', 'bo': 'མ་ནི་ལ།', 'nn': 'Manila', 'qu': 'Manila', 'rw': 'Manila', 'si': 'මැනිලා', 'mi': 'Manira', 'li': 'Manilla', 'pl': 'Manila', 'na': 'Manila', 'az': 'Manila', 'am': 'ማኒላ', 'da': 'Manila', 'ps': 'مانیلا', 'br': 'Manila', 'vi': 'Manila', 'mr': 'मनिला', 'et': 'Manila', 'en': 'Manila', 'ht': 'Manyl', 'no': 'Manila', 'vo': 'Maynila', 'fa': 'مانیل', 'tg': 'Манила', 'oc': 'Manila', 'lb': 'Manila', 'is': 'Maníla', 'jv': 'Manila', 'cs': 'Manila', 'he': 'מנילה', 'os': 'Манилæ', 'el': 'Μανίλα', 'zh': '马尼拉 / 馬尼拉', 'mn': 'Манила', 'ml': 'മനില', 'mk': 'Манила', 'ce': 'Манила', 'gd': 'Manila', 'bg': 'Манила', 'io': 'Manila', 'sn': 'Manila', 'sv': 'Manila', 'sr': 'Манила', 'sq': 'Manila', 'fi': 'Manila', 'my': 'မနီလာမြို့', 'es': 'Manila', 'eu': 'Manila', 'ka': 'მანილა', 'nl': 'Manilla', 'or': 'ମାନିଲା', 'ki': 'Manila', 'tt': 'Манила', 'sc': 'Manila', 'hi': 'मनीला'}, 'lat': 14.5948914, 'lon': 120.9782618, 'country': 'PH'}, {'name': 'Manila', 'lat': 35.8800733, 'lon': -90.1670393, 'country': 'US', 'state': 'Arkansas'}, {'name': 'Manila', 'lat': 40.8517929, 'lon': -124.1622856, 'country': 'US', 'state': 'California'}, {'name': 'Manila', 'lat': 37.9867678, 'lon': -81.9429031, 'country': 'US', 'state': 'West Virginia'}, {'name': 'Manila', 'lat': 29.73862, 'lon': 79.19907, 'country': 'IN', 'state': 'Uttarakhand'}]

# %%
# Send GET Request
